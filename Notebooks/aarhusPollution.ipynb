# %%
import sys
# import packages
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# %%
import os

path = os.path.join('C:' + os.sep, 'Users', 'c0044008', 'OneDrive - Newcastle University', 'Datasets', 'aarhusPollution.csv')
aarhusPoll = pd.read_csv(path, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
# Out:
# C:\Users\c0044008\AppData\Local\Temp\ipykernel_13400\3915803693.py:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   aarhusPoll = pd.read_csv(path, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')

# %%
aarhusPoll
# Out:
#                            ozone particullate_matter carbon_monoxide  \
# 0                            101                  94              49
# 1                            106                  97              48
# 2                            107                  95              49
# 3                            103                  90              51
# 4                            105                  94              49
# ...                          ...                 ...             ...
# 7887970                      202                 192             196
# 7887971                      202                 193             199
# 7887972                      199                 194             197
# 7887973                      200                 190             193
# 7887974  (7887974 rows affected)                 NaN             NaN
#
#         sulfure_dioxide nitrogen_dioxide         longitude          latitude  \
# ...

# %%
print(aarhusPoll.head())
aarhusPoll['timestamp'] = pd.to_datetime(aarhusPoll['timestamp']).astype('int64')
aarhusPoll.dropna()
# Filter/clean data (not needed here) and define X and y:
X = aarhusPoll.iloc[:,:-1].values
y = aarhusPoll.iloc[:,1].values
# Out:
#   ozone particullate_matter carbon_monoxide sulfure_dioxide nitrogen_dioxide  \
# 0   101                  94              49              44               87
# 1   106                  97              48              47               86
# 2   107                  95              49              42               85
# 3   103                  90              51              44               87
# 4   105                  94              49              39               82
#
#           longitude          latitude            timestamp ReportID
# 0  10.1049860760575  56.2317206942822  1406851500000000000   158324
# 1  10.1049860760575  56.2317206942822  1406851800000000000   158324
# 2  10.1049860760575  56.2317206942822  1406852100000000000   158324
# 3  10.1049860760575  56.2317206942822  1406852400000000000   158324
# 4  10.1049860760575  56.2317206942822  1406852700000000000   158324
# [['101' '94' '49' ... '10.1049860760575' '56.2317206942822'
#   1406851500000000000]
# ...

# %%
for e in X:
    if (!e.is_numeric()):
        print(e)

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test2, y_train, y_test2 = train_test_split(X, y, test_size=0.20)  



# Scale data:
from sklearn.preprocessing import StandardScaler  
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test2 = scaler.transform(X_test2)
