# %%
# %pip freeze > requirements.txt
# %pip install -r requirements.txt
import requests
from IPython.display import GeoJSON
import pandas as pd
import io
import seaborn as sns
import numpy as np
from datetime import datetime, timedelta
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: affine==2.4.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: ansi2html==1.8.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: anyio==3.6.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 3)) (3.6.2)
# Requirement already satisfied: argon2-cffi==21.3.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 4)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 5)) (21.2.0)
# Requirement already satisfied: arrow==1.2.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 6)) (1.2.3)
# Requirement already satisfied: asttokens==2.2.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: attrs==23.1.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 8)) (23.1.0)
# Requirement already satisfied: backcall==0.2.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.12.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 10)) (4.12.2)
# Requirement already satisfied: bleach==6.0.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 11)) (6.0.0)
# Requirement already satisfied: branca==0.6.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 12)) (0.6.0)
# Requirement already satisfied: certifi==2022.12.7 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 13)) (2022.12.7)
# Requirement already satisfied: cffi==1.15.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 14)) (1.15.1)
# Requirement already satisfied: charset-normalizer==3.1.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 15)) (3.1.0)
# Requirement already satisfied: click==8.1.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 16)) (8.1.3)
# Requirement already satisfied: click-plugins==1.1.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 17)) (1.1.1)
# Requirement already satisfied: cligj==0.7.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 18)) (0.7.2)
# Requirement already satisfied: cmdstanpy==1.1.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 19)) (1.1.0)
# Requirement already satisfied: colorama==0.4.6 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 20)) (0.4.6)
# Requirement already satisfied: comm==0.1.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 21)) (0.1.3)
# Requirement already satisfied: contextily==1.3.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 22)) (1.3.0)
# Requirement already satisfied: contourpy==1.0.7 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 23)) (1.0.7)
# Requirement already satisfied: convertdate==2.4.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 24)) (2.4.0)
# Requirement already satisfied: cycler==0.11.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 25)) (0.11.0)
# Requirement already satisfied: dash==2.9.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 26)) (2.9.3)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 27)) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 28)) (2.0.0)
# Requirement already satisfied: dash-renderer==1.9.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 29)) (1.9.1)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 30)) (5.0.0)
# Requirement already satisfied: debugpy==1.6.7 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 31)) (1.6.7)
# Requirement already satisfied: decorator==5.1.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 32)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 33)) (0.7.1)
# Requirement already satisfied: ephem==4.1.4 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 34)) (4.1.4)
# Requirement already satisfied: executing==1.2.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 35)) (1.2.0)
# Requirement already satisfied: fastjsonschema==2.16.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 36)) (2.16.3)
# Requirement already satisfied: Fiona==1.9.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 37)) (1.9.3)
# Requirement already satisfied: Flask==2.2.4 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 38)) (2.2.4)
# Requirement already satisfied: folium==0.14.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 39)) (0.14.0)
# Requirement already satisfied: fonttools==4.39.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 40)) (4.39.3)
# Requirement already satisfied: fqdn==1.5.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 41)) (1.5.1)
# Requirement already satisfied: geographiclib==2.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 42)) (2.0)
# Requirement already satisfied: geopandas==0.12.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 43)) (0.12.2)
# Requirement already satisfied: geopy==2.3.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 44)) (2.3.0)
# Requirement already satisfied: hijri-converter==2.2.4 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 45)) (2.2.4)
# Requirement already satisfied: holidays==0.23 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 46)) (0.23)
# Requirement already satisfied: idna==3.4 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 47)) (3.4)
# Requirement already satisfied: ipykernel==6.22.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 48)) (6.22.0)
# Requirement already satisfied: ipython==8.12.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 49)) (8.12.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 50)) (0.2.0)
# Requirement already satisfied: ipywidgets==8.0.6 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 51)) (8.0.6)
# Requirement already satisfied: isoduration==20.11.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 52)) (20.11.0)
# Requirement already satisfied: itsdangerous==2.1.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 53)) (2.1.2)
# Requirement already satisfied: jedi==0.18.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 54)) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 55)) (3.1.2)
# Requirement already satisfied: joblib==1.2.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 56)) (1.2.0)
# Requirement already satisfied: jsonpointer==2.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 57)) (2.3)
# Requirement already satisfied: jsonschema==4.17.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 58)) (4.17.3)
# Requirement already satisfied: jupyter-dash==0.4.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 59)) (0.4.2)
# Requirement already satisfied: jupyter-events==0.6.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 60)) (0.6.3)
# Requirement already satisfied: jupyter_client==8.2.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 61)) (8.2.0)
# Requirement already satisfied: jupyter_core==5.3.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 62)) (5.3.0)
# Requirement already satisfied: jupyter_server==2.5.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 63)) (2.5.0)
# Requirement already satisfied: jupyter_server_terminals==0.4.4 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 64)) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 65)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets==3.0.7 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 66)) (3.0.7)
# Requirement already satisfied: kiwisolver==1.4.4 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 67)) (1.4.4)
# Requirement already satisfied: korean-lunar-calendar==0.3.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 68)) (0.3.1)
# Requirement already satisfied: LunarCalendar==0.0.9 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 69)) (0.0.9)
# Requirement already satisfied: MarkupSafe==2.1.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 70)) (2.1.2)
# Requirement already satisfied: matplotlib==3.7.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 71)) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 72)) (0.1.6)
# Requirement already satisfied: mercantile==1.2.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 73)) (1.2.1)
# Requirement already satisfied: mistune==2.0.5 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 74)) (2.0.5)
# Requirement already satisfied: munch==2.5.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 75)) (2.5.0)
# Requirement already satisfied: nbclassic==0.5.5 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 76)) (0.5.5)
# Requirement already satisfied: nbclient==0.7.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 77)) (0.7.3)
# Requirement already satisfied: nbconvert==7.3.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 78)) (7.3.1)
# Requirement already satisfied: nbformat==5.8.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 79)) (5.8.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 80)) (1.5.6)
# Requirement already satisfied: notebook==6.5.4 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 81)) (6.5.4)
# Requirement already satisfied: notebook_shim==0.2.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 82)) (0.2.2)
# Requirement already satisfied: numpy==1.24.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 83)) (1.24.3)
# Requirement already satisfied: packaging==23.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 84)) (23.1)
# Requirement already satisfied: pandas==2.0.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 85)) (2.0.0)
# Requirement already satisfied: pandocfilters==1.5.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 86)) (1.5.0)
# Requirement already satisfied: parso==0.8.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 87)) (0.8.3)
# Requirement already satisfied: pickleshare==0.7.5 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 88)) (0.7.5)
# Requirement already satisfied: Pillow==9.5.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 89)) (9.5.0)
# Requirement already satisfied: platformdirs==3.2.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 90)) (3.2.0)
# Requirement already satisfied: plotly==5.14.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 91)) (5.14.1)
# Requirement already satisfied: prometheus-client==0.16.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 92)) (0.16.0)
# Requirement already satisfied: prompt-toolkit==3.0.38 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 93)) (3.0.38)
# Requirement already satisfied: prophet==1.1.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 94)) (1.1.2)
# Requirement already satisfied: psutil==5.9.5 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 95)) (5.9.5)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 96)) (0.2.2)
# Requirement already satisfied: pycparser==2.21 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 97)) (2.21)
# Requirement already satisfied: Pygments==2.15.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 98)) (2.15.1)
# Requirement already satisfied: PyMeeus==0.5.12 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 99)) (0.5.12)
# Requirement already satisfied: pyparsing==3.0.9 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 100)) (3.0.9)
# Requirement already satisfied: pyproj==3.5.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 101)) (3.5.0)
# Requirement already satisfied: pyrsistent==0.19.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 102)) (0.19.3)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 103)) (2.8.2)
# Requirement already satisfied: python-json-logger==2.0.7 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 104)) (2.0.7)
# Requirement already satisfied: pytz==2023.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 105)) (2023.3)
# Requirement already satisfied: pywin32==306 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 106)) (306)
# Requirement already satisfied: pywinpty==2.0.10 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 107)) (2.0.10)
# Requirement already satisfied: PyYAML==6.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 108)) (6.0)
# Requirement already satisfied: pyzmq==25.0.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 109)) (25.0.2)
# Requirement already satisfied: rasterio==1.3.6 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 110)) (1.3.6)
# Requirement already satisfied: requests==2.28.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 111)) (2.28.2)
# Requirement already satisfied: retrying==1.3.4 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 112)) (1.3.4)
# Requirement already satisfied: rfc3339-validator==0.1.4 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 113)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 114)) (0.1.1)
# Requirement already satisfied: scikit-learn==1.2.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 115)) (1.2.2)
# Requirement already satisfied: scipy==1.10.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 116)) (1.10.1)
# Requirement already satisfied: seaborn==0.12.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 117)) (0.12.2)
# Requirement already satisfied: Send2Trash==1.8.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 118)) (1.8.0)
# Requirement already satisfied: shapely==2.0.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 119)) (2.0.1)
# Requirement already satisfied: six==1.16.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 120)) (1.16.0)
# Requirement already satisfied: smopy==0.0.8 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 121)) (0.0.8)
# Requirement already satisfied: sniffio==1.3.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 122)) (1.3.0)
# Requirement already satisfied: snuggs==1.4.7 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 123)) (1.4.7)
# Requirement already satisfied: soupsieve==2.4.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 124)) (2.4.1)
# Requirement already satisfied: stack-data==0.6.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 125)) (0.6.2)
# Requirement already satisfied: style==1.1.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 126)) (1.1.0)
# Requirement already satisfied: tenacity==8.2.2 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 127)) (8.2.2)
# Requirement already satisfied: terminado==0.17.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 128)) (0.17.1)
# Requirement already satisfied: threadpoolctl==3.1.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 129)) (3.1.0)
# Requirement already satisfied: tinycss2==1.2.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 130)) (1.2.1)
# Requirement already satisfied: tornado==6.3.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 131)) (6.3.1)
# Requirement already satisfied: tqdm==4.65.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 132)) (4.65.0)
# Requirement already satisfied: traitlets==5.9.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 133)) (5.9.0)
# Requirement already satisfied: tzdata==2023.3 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 134)) (2023.3)
# Requirement already satisfied: update==0.0.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 135)) (0.0.1)
# Requirement already satisfied: uri-template==1.2.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 136)) (1.2.0)
# Requirement already satisfied: urllib3==1.26.15 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 137)) (1.26.15)
# Requirement already satisfied: wcwidth==0.2.6 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 138)) (0.2.6)
# Requirement already satisfied: webcolors==1.13 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 139)) (1.13)
# Requirement already satisfied: webencodings==0.5.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 140)) (0.5.1)
# Requirement already satisfied: websocket-client==1.5.1 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 141)) (1.5.1)
# Requirement already satisfied: Werkzeug==2.3.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 142)) (2.3.0)
# Requirement already satisfied: widgetsnbextension==4.0.7 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 143)) (4.0.7)
# Requirement already satisfied: xyzservices==2023.2.0 in c:\users\c0044008\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 144)) (2023.2.0)
# Requirement already satisfied: setuptools in c:\program files\python310\lib\site-packages (from rasterio==1.3.6->-r requirements.txt (line 110)) (65.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import smopy
import matplotlib.patheffects as pe

sensor_params_pm2 = dict(
    sensor_type='PM2.5')

sensor_params_pm10 = dict(
    sensor_type='PM10')

sensor_params_no2 = dict(
    sensor_type='NO2')

def create_map(sensor_params):
    r = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/csv/',sensor_params)

    sensor_info = pd.read_csv(io.StringIO(r.text) )
    sensor_info
    
    bbox = (
    min(sensor_info['Sensor Centroid Latitude']),
        min(sensor_info['Sensor Centroid Longitude']),
        max(sensor_info['Sensor Centroid Latitude']),
        max(sensor_info['Sensor Centroid Longitude']),
    )

    map = smopy.Map(bbox, z=10)
    ax = map.show_mpl(figsize=(15, 15))
    for i,row in sensor_info.iterrows():
        x, y = map.to_pixels(row['Sensor Centroid Latitude'], row['Sensor Centroid Longitude'])
        ax.plot(x, y, 'ob', ms=20, mew=2);
        
        
create_map(sensor_params_pm2)

# %%
class AggData:
    instances = []
    data_params = {}
    df = pd.DataFrame()

    def __init__(self, variable):
        # Set up parameters
        self.data_params = dict(
            data_variable=variable,
            agg_method='median',
            agg_period='15mins',
            starttime=(datetime.now() - timedelta(days=1)).strftime("%Y%m%d%H%M%S"),
            endtime=datetime.now().strftime("%Y%m%d%H%M%S"),
            sensor_type=variable
        )

        # Call fetch data method
        self.df = AggData.FetchAggData(self.data_params)

        # Append to instances of this class
        AggData.instances.append(self)

    @classmethod
    def FetchAggData(cls, data_params):
        r = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/', data_params)
        df = pd.read_csv(io.StringIO(r.text))
        return df

    def __str__(self):
        return f"{self.data_params['data_variable']}"

# %%
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

def plot_line_graph(df, data_params, figsize=(15, 10)):
    fig, ax = plt.subplots(figsize=figsize)

    for sensor_name, sensor_data in df.groupby('Sensor Name'):
        datetimes = pd.to_datetime(sensor_data['Timestamp'])
        plt.plot(datetimes, sensor_data['Value'], label=sensor_name)
        plt.xlabel("MMDDHH")
        # Add units to the y-axis label
        ylabel = f"{data_params['data_variable']} (unit)"
        plt.ylabel(ylabel)

    plt.legend()
    plt.tight_layout()

    
a = AggData("PM2.5")
plot_line_graph(a.df, a.data_params)

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline


def box_plots(df, data_params):
    
#     print(df.shape)
    fig, ax = plt.subplots()
    sns.set_style("whitegrid")
    
    ax.set_aspect=(1.5) 
    flierprops = dict(markerfacecolor='0.75', markersize=5, linestyle='none')

    sns.boxplot(x=df['Value'], width=0.6, color=".65", flierprops=flierprops)
    plt.xlabel(data_params["data_variable"])
    plt.show()

    sns.boxplot(x=df['Value'], width=0.6, color=".65", showfliers=False)
    plt.xlabel(data_params["data_variable"]+" (outliers removed)")
    plt.show()
    
def kde_plot(df):
    # kde plot
    sns.displot(data=df, x=df['Value'], kind="kde")
    sns.displot(data=df, x=df['Value'])
    plt.show()

for i in range(0, len(AggData.instances)):
    box_plots(AggData.instances[i].df, AggData.instances[i].data_params)

# %%
def Remove_Suspect(df):
    
    # Drop rows containing NaN values
    df.dropna(inplace=True)

    # Remove rows with 'Value' <= 0
    df = df[df['Value'] > 0]

    # Remove flagged as suspect readings
    df = df[df['Flagged as Suspect Reading'] == False]

    return df


def Remove_Outlier_Indices(df):
    
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    IQR = Q3 - Q1
    trueList = ~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR)))
    return trueList


def iqr_method(df):
    
    nonOutliers = Remove_Outlier_Indices(df['Value'])

    # Non-Outlier Subset of the Given Dataset
    dfIQR = df[nonOutliers]
    return dfIQR

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, LineString
import numpy as np
import contextily as ctx

def plot_sensor_spikes(df, scale_factor=40):
    # Convert the DataFrame to a GeoDataFrame
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['Sensor Centroid Longitude'], df['Sensor Centroid Latitude']))

    # Set CRS for the GeoDataFrame
    gdf = gdf.set_crs("EPSG:4326")
    gdf = gdf.to_crs("EPSG:3857")

    # Set all angles to 0 degrees (up)
    gdf['angle'] = 0

    # Create the create_spike function as before, but set the angle to 0 degrees (up)
    def create_spike(row, scale_factor):
        centroid = row.geometry.centroid
        spike_length = row['Value'] * scale_factor
        angle = 0  # Set the angle to 0 degrees (up)

        end_y = centroid.y + spike_length * np.cos(np.deg2rad(angle))
        end_x = centroid.x + spike_length * np.sin(np.deg2rad(angle))
        spike_line = LineString([(centroid.x, centroid.y), (end_x, end_y)])

        return spike_line

    # Create a copy of the GeoDataFrame and apply the create_spike function
    gdf_spikes = gdf.copy()
    gdf_spikes['geometry'] = gdf.apply(create_spike, scale_factor=scale_factor, axis=1)

    # Plot the spikes on the map
    fig, ax = plt.subplots(figsize=(10, 10))
    gdf.geometry.plot(ax=ax, markersize=10, color='blue')  # Plot the sensor locations
    gdf_spikes.plot(ax=ax, linewidth=2, color='red')  # Plot the spikes
    plt.axis('equal')  # Set equal aspect ratio

    # Add basemap
    ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)
    ax.set_axis_off()

    plt.show()

# %%
import folium
from folium.plugins import MarkerCluster

def create_sensor_spike_map(gdf, location=[54.9714, -1.6174], zoom_start=12, scale_factor=30):
    # Create an empty Folium Map object centered at Newcastle upon Tyne
    m = folium.Map(location=location, zoom_start=zoom_start)

    # Filter out rows with missing values
    gdf_filtered = gdf.dropna(subset=['Value'])

    # Iterate through the filtered GeoDataFrame and add each spike to the map
    for index, row in gdf_filtered.iterrows():
        # Create the spike
        centroid = row.geometry.centroid
        spike_length = row['Value'] * scale_factor
        angle = 0  # Set the angle to 0 degrees (up)

        end_y = centroid.y + spike_length * np.cos(np.deg2rad(angle))
        end_x = centroid.x + spike_length * np.sin(np.deg2rad(angle))
        spike_line = LineString([(centroid.x, centroid.y), (end_x, end_y)])

        # Convert the spike's coordinates from Web Mercator to WGS84
        spike_wgs84 = gpd.GeoSeries(spike_line, crs="EPSG:3857").to_crs("EPSG:4326").iloc[0]

        # Add the spike to the map
        folium.PolyLine(
            locations=[(spike_wgs84.coords[0][1], spike_wgs84.coords[0][0]),
                       (spike_wgs84.coords[1][1], spike_wgs84.coords[1][0])],
            color='red',
            weight=2.5,
            opacity=0.8
        ).add_to(m)

    return m

# %%
from prophet import Prophet
from sklearn.metrics import mean_absolute_error

def prophet_forecast(input_df):
    # Clean and prepare the data
    df = Remove_Suspect(input_df.df)
    df = iqr_method(df)
    # Select relevant columns and rename them as required by Prophet
    df = df[['Timestamp', 'Value']]
    df.columns = ['ds', 'y']

    # Make sure the 'ds' column is in datetime format
    df['ds'] = pd.to_datetime(df['ds'])

    # Split the data into train and test sets (80% train, 20% test)
    train_size = int(0.8 * len(df))
    train_df = df.iloc[:train_size]
    test_df = df.iloc[train_size:]

    # Initialize and fit the Prophet model with tuned hyperparameters
    model = Prophet(seasonality_mode='multiplicative', changepoint_prior_scale=0.5, yearly_seasonality=10, weekly_seasonality=True)
    model.fit(train_df)

    # Make predictions for the test set
    future = model.make_future_dataframe(periods=len(test_df), freq='H')
    forecast = model.predict(future)

    # Plot the predictions
    fig = model.plot(forecast)

    # Set the Y-axis label
    ax = fig.gca()
    ax.set_ylabel(str(input_df) +' Measurement Value')

    # Optionally, you can set the X-axis label as well
    ax.set_xlabel('Time')

    plt.show()

    # Calculate the Mean Absolute Error (MAE) to evaluate the model's performance
    mae = mean_absolute_error(test_df['y'], forecast['yhat'].tail(len(test_df)))
    print(f"Mean Absolute Error: {mae:.2f}")

    return mae

a=AggData("PM10")
prophet_forecast(a)
# Out:
# 20:55:03 - cmdstanpy - INFO - Chain [1] start processing
# 20:55:05 - cmdstanpy - INFO - Chain [1] done processing
# Mean Absolute Error: 22.64
# 22.635086239349995

# %%
from ipywidgets import interactive, Layout, widgets

# Create a dropdown widget to select the plot type
plot_type_selector = widgets.Dropdown(options=['Line Graph', 'KDE Plot', 'Sensor Spike Map', 'Sensor Map', 'Prophet Forecast'], description='Plot Type:', layout=Layout(width='auto', height='auto'))

# Create a widget to hold the plot output
plot_output = widgets.Output(layout=widgets.Layout(width='100%', height='auto', overflow='visible'))

# %matplotlib inline
import matplotlib.pyplot as plt

#plt.rcParams['figure.figsize'] = [20, 12]  # Increase the figure size here
#plt.rcParams['figure.dpi'] = 100


def plot_dashboard(variable1, variable2, plot_type):
    
    # Find the AggData instance with the selected data variables
    selected_agg_data1 = None
    selected_agg_data2 = None
    for instance in AggData.instances:
        if instance.data_params["data_variable"] == variable1:
            selected_agg_data1 = instance
        if instance.data_params["data_variable"] == variable2:
            selected_agg_data2 = instance
        if selected_agg_data1 is not None and selected_agg_data2 is not None:
            break

    if selected_agg_data1 is not None and selected_agg_data2 is not None:
        # Clear the plot output widget
        plot_output.clear_output()
        
        # Plot the data based on the selected plot type
        with plot_output:

            if plot_type == 'Line Graph':
                #plot_line_graph(selected_agg_data1.df, selected_agg_data1.data_params)
                df1 = Remove_Suspect(selected_agg_data1.df)
                dfIQR1 = iqr_method(df1)
                print("Outliers Removed:")
                plot_line_graph(dfIQR1, selected_agg_data1.data_params)

                #plot_line_graph(selected_agg_data2.df, selected_agg_data2.data_params)
                df2 = Remove_Suspect(selected_agg_data2.df)
                dfIQR2 = iqr_method(df2)
                print("Outliers Removed:")
                plot_line_graph(dfIQR2, selected_agg_data2.data_params)

            elif plot_type == 'KDE Plot':
                df1 = Remove_Suspect(selected_agg_data1.df)
                dfIQR1 = iqr_method(df1)
                kde_plot(df1)

            elif plot_type == 'Sensor Spike Map':
                df1 = Remove_Suspect(selected_agg_data1.df)
                dfIQR1 = iqr_method(df1)
                gdf = gpd.GeoDataFrame(dfIQR1, geometry=gpd.points_from_xy(dfIQR1['Sensor Centroid Longitude'],dfIQR1['Sensor Centroid Latitude']))
                sensor_spike_map = create_sensor_spike_map(gdf, location=[54.9714, -1.6174], zoom_start=12, scale_factor=30)
                display(sensor_spike_map)

            elif plot_type == 'Sensor Map':
                df1 = Remove_Suspect(selected_agg_data1.df)
                dfIQR1 = iqr_method(df1)
                gdf = gpd.GeoDataFrame(dfIQR1, geometry=gpd.points_from_xy(dfIQR1['Sensor Centroid Longitude'], dfIQR1['Sensor Centroid Latitude']))
                plot_sensor_spikes(gdf)

            elif plot_type == 'Prophet Forecast':
                print("Prophet Forecast for Variable 1:")
                prophet_forecast(selected_agg_data1)

                print("Prophet Forecast for Variable 2:")
                prophet_forecast(selected_agg_data2)



                
def update_plot_type_options(change):
    if change['new'] in ['Sensor Spike Map', 'Sensor Map', 'KDE Plot']:
        variable_selector2.disabled = True
    else:
        variable_selector1.disabled = False
        variable_selector2.disabled = False

plot_type_selector.observe(update_plot_type_options, 'value')
# Create dropdown widgets to select the variables
variable_selector1 = widgets.Dropdown(options=['PM2.5', 'PM10', 'NO2'], description='Variable 1:', layout=Layout(width='auto', height='auto'))
variable_selector2 = widgets.Dropdown(options=['PM2.5', 'PM10', 'NO2'], description='Variable 2:', layout=Layout(width='auto', height='auto'))

dashboard = interactive(plot_dashboard, variable1=variable_selector1, variable2=variable_selector2, plot_type=plot_type_selector)
box_layout = widgets.Layout(display='flex', flex_flow='column', align_items='stretch', width='100%')
display(widgets.Box([variable_selector1, variable_selector2, plot_type_selector, plot_output, dashboard.children[-1]], layout=box_layout))
# Out:
# Box(children=(Dropdown(description='Variable 1:', layout=Layout(height='auto', width='auto'), options=('PM2.5'…

# %%
from ipywidgets import Tab

line_graph_tab = widgets.VBox([variable_selector1, variable_selector2, plot_output, dashboard.children[-1]])
kde_plot_tab = widgets.VBox([variable_selector1, variable_selector2, plot_output, dashboard.children[-1]])
sensor_spike_map_tab = widgets.VBox([plot_output])
sensor_map_tab = widgets.VBox([variable_selector1, variable_selector2, plot_output, dashboard.children[-1]])
prophet_forecast_tab = widgets.VBox([variable_selector1, variable_selector2, plot_output, dashboard.children[-1]])

tab_widget = Tab()
tab_widget.children = [line_graph_tab, kde_plot_tab, sensor_spike_map_tab, sensor_map_tab, prophet_forecast_tab]
tab_widget.set_title(0, 'Line Graph')
tab_widget.set_title(1, 'KDE Plot')
tab_widget.set_title(2, 'Sensor Spike Map')
tab_widget.set_title(3, 'Sensor Map')
tab_widget.set_title(4, 'Prophet Forecast')

# Display the tab widget
display(tab_widget)
# Out:
# Tab(children=(VBox(children=(Dropdown(description='Variable 1:', layout=Layout(height='auto', width='auto'), o…
